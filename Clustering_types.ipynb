# %% [markdown]
# Clustering Type

# %% [markdown]
# 1. Partitioning Clustering — K-Means

# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"

import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

X = np.array([[1,2],[1.5,1.8],[5,8],[8,8],[1,0.6],[9,11]])

kmeans = KMeans(n_clusters=2)

kmeans.fit(X)

labels = kmeans.labels_
centroids = kmeans.cluster_centers_

plt.scatter(X[:,0], X[:,1], c=labels)
plt.scatter(centroids[:,0], centroids[:,1], marker='x')
plt.show()
# Out:
# C:\Users\KIIT0001\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# 2. Hierarchical Clustering

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering

# Sample data
X = np.array([[1,2],[1.5,1.8],[5,8],[8,8],[1,0.6],[9,11]])

# Hierarchical clustering
model = AgglomerativeClustering(n_clusters=2)
labels = model.fit_predict(X)

plt.scatter(X[:,0], X[:,1], c=labels)
plt.show()

# %% [markdown]
# 3. Density-Based Clustering

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

X = np.array([[1,2],[2,2],[2,3],[8,7],[8,8],[25,80]])

db = DBSCAN(eps=3, min_samples=2)
labels = db.fit_predict(X)

plt.scatter(X[:,0], X[:,1], c=labels)
plt.show()

# %% [markdown]
# 4. Grid-Based Clustering

# %%
import numpy as np

# Sample data
X = np.random.rand(10,2)

# Define grid size
grid_size = 0.5

grid_cells = {}

for point in X:
    cell = (int(point[0]/grid_size), int(point[1]/grid_size))
    if cell not in grid_cells:
        grid_cells[cell] = []
    grid_cells[cell].append(point)

print("Grid clusters:", grid_cells)
# Out:
# Grid clusters: {(0, 1): [array([0.4784458 , 0.69570252]), array([0.23123362, 0.75659325])], (0, 0): [array([0.3999477 , 0.49528471]), array([0.47206778, 0.02038921]), array([0.40102963, 0.26311299]), array([0.22686912, 0.24865951])], (1, 0): [array([0.63358888, 0.21457401]), array([0.54750918, 0.31449358]), array([0.91637494, 0.21268849]), array([0.83677224, 0.15453713])]}

# %% [markdown]
# 5. Model-Based Clustering

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture

X = np.array([[1,2],[1.5,1.8],[5,8],[8,8],[1,0.6],[9,11]])

gmm = GaussianMixture(n_components=2)
labels = gmm.fit_predict(X)

plt.scatter(X[:,0], X[:,1], c=labels)
plt.show()
# Out:
# C:\Users\KIIT0001\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
